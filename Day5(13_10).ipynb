# %% [markdown]
# <a href="https://colab.research.google.com/github/ashikha-03/Pandas/blob/main/Day5(13_10).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
a=np.array([10,12,14,16,18])
a
# Out:
# array([10, 12, 14, 16, 18])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a[1]
# Out:
# 12

# %%
s=pd.Series([10,12,14,16,18])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    10
# 1    12
# 2    14
# 3    16
# 4    18
# dtype: int64

# %%
s[3]
# Out:
# 16

# %%
s.drop([4])
# Out:
# 0    10
# 1    12
# 2    14
# 3    16
# dtype: int64

# %%
s
# Out:
# 0    10
# 1    12
# 2    14
# 3    16
# 4    18
# dtype: int64

# %%
s.iloc[3]
# Out:
# 16

# %%
s.loc[4]
# Out:
# 18

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
s.drop(3,inplace=True)

# %%
s
# Out:
# 0    10
# 1    12
# 2    14
# 4    18
# dtype: int64

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
ss=pd.Series([10,20,30,40,50],index=['a','b','c','d','e'])
ss
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
s1=pd.Series([10,20,30,40,50],index=['a','a','c','d','e'])
s1.loc['a']
# Out:
# a    10
# a    20
# dtype: int64

# %%
data=[['Ashi',19,'03-01-2004'],['Hari',None,None],['Sarasu',None,'10-06-2004']]
data
# Out:
# [['Ashi', 19, '03-01-2004'],
#  ['Hari', None, None],
#  ['Sarasu', None, '10-06-2004']]

# %%
df=pd.DataFrame(data)
df
# Out:
#         0     1           2
# 0    Ashi  19.0  03-01-2004
# 1    Hari   NaN        None
# 2  Sarasu   NaN  10-06-2004

# %%
df[0:1]
# Out:
#       0     1           2
# 0  Ashi  19.0  03-01-2004

# %%
df[[0,2]]
# Out:
#         0           2
# 0    Ashi  03-01-2004
# 1    Hari        None
# 2  Sarasu  10-06-2004

# %%
df[0:1]
# Out:
#       0     1           2
# 0  Ashi  19.0  03-01-2004

# %%
df=pd.DataFrame(data,columns=['Name','Age','Dob'])
df
# Out:
#      Name   Age         Dob
# 0    Ashi  19.0  03-01-2004
# 1    Hari   NaN        None
# 2  Sarasu   NaN  10-06-2004

# %%
df['Name']
# Out:
# 0      Ashi
# 1      Hari
# 2    Sarasu
# Name: Name, dtype: object

# %%
df['Age']
# Out:
# 0    19.0
# 1     NaN
# 2     NaN
# Name: Age, dtype: float64

# %%
df['Name'][0]
# Out:
# 'Ashi'

# %%
df.loc[0,'Name']
# Out:
# 'Ashi'

# %%
df.iloc[0,0]
# Out:
# 'Ashi'

# %%
df.loc[1]
# Out:
# Name    Hari
# Age      NaN
# Dob     None
# Name: 1, dtype: object

# %%
df[0:1]
# Out:
#    Name   Age         Dob
# 0  Ashi  19.0  03-01-2004

# %%
s=pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s.plot()
# Out:
# <Axes: >

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
s.hist(bins=10)
# Out:
# <Axes: >

# %%
s=s.to_numpy()
s
# Out:
# array([1, 2, 3, 4])

# %%
type(s)
# Out:
# numpy.ndarray

# %%
df.head(1)
# Out:
#    Name   Age         Dob
# 0  Ashi  19.0  03-01-2004

# %%
df.tail(-2)
# Out:
#      Name  Age         Dob
# 2  Sarasu  NaN  10-06-2004

# %%
df.isnull()
# Out:
#     Name    Age    Dob
# 0  False  False  False
# 1  False   True   True
# 2  False   True  False

# %%
df.isnull().sum()
# Out:
# Name    0
# Age     2
# Dob     1
# dtype: int64

# %%
#None,' ',"",'-','?','Nil',np.nan(not a number)

# %%
S=pd.DataFrame([["ASHI",8,"IT",7.67],["HARI",40,None,9.67],["HARITHA",None,"IT",None]])
S
# Out:
#          0     1     2     3
# 0     ASHI   8.0    IT  7.67
# 1     HARI  40.0  None  9.67
# 2  HARITHA   NaN    IT   NaN

# %%
#axis=1 indicates column, axis=0 indicates row

# %%
S.drop([2],axis=1,inplace=True)
S
# Out:
#          0     1     3
# 0     ASHI   8.0  7.67
# 1     HARI  40.0  9.67
# 2  HARITHA   NaN   NaN

# %%
S.drop?

# %%
S.dropna()
# Out:
#       0     1     3
# 0  ASHI   8.0  7.67
# 1  HARI  40.0  9.67

# %%
S=pd.DataFrame([["ASHI",8,"IT",7.67],["HARI",40,None,9.67],["HARITHA",None,"IT",None],['Anu',None,None,8.6]])
S
S.drop([0,2])
# Out:
#       0     1     2     3
# 1  HARI  40.0  None  9.67
# 3   Anu   NaN  None  8.60

# %%
a=np.array([10,11,14,15,18,20])
a
# Out:
# array([10, 11, 14, 15, 18, 20])

# %%
a>15
# Out:
# array([False, False, False, False,  True,  True])

# %%
a[a>15]
# Out:
# array([18, 20])

# %%
a[a%2==0]
# Out:
# array([10, 14, 18, 20])

# %%
a[a%2!=0]
# Out:
# array([11, 15])

# %%
S=pd.DataFrame([["ASHI",8,"IT",7.67],["HARI",40,None,9.67],["HARITHA",None,"IT",None],['Anu',None,None,8.6]])
S.info()#datatypes,class,columnno,columnname,nullvalue
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4 non-null      object
#  1   1       2 non-null      float64
#  2   2       2 non-null      object
#  3   3       3 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 256.0+ bytes

# %%
S[0].str.contains('R')
# Out:
# 0    False
# 1     True
# 2     True
# 3    False
# Name: 0, dtype: bool

# %%
data=[['Ashi',19,'03-01-2004'],['Hari',None,None],['Sarasu',None,'10-06-2004']]
df=pd.DataFrame(data,columns=['Name','Age','Dob'])
df['Name'].str.contains('i')
# Out:
# 0     True
# 1     True
# 2    False
# Name: Name, dtype: bool

# %%
print(df.values)
print()
print(df.columns)
print()
print(df.index)
print()
print(df.dtypes)
print()
print(df.ndim)
print()
print(df.axes)
print()
print(df.size)
print()
print(df.shape)
# Out:
# [['Ashi' 19.0 '03-01-2004']
#  ['Hari' nan None]
#  ['Sarasu' nan '10-06-2004']]
#
# Index(['Name', 'Age', 'Dob'], dtype='object')
#
# RangeIndex(start=0, stop=3, step=1)
#
# Name     object
# Age     float64
# Dob      object
# dtype: object
#
# 2
#
# [RangeIndex(start=0, stop=3, step=1), Index(['Name', 'Age', 'Dob'], dtype='object')]
#
# 9
#
# (3, 3)

# %%
df.tail()
# Out:
#      Name   Age         Dob
# 0    Ashi  19.0  03-01-2004
# 1    Hari   NaN        None
# 2  Sarasu   NaN  10-06-2004

# %%
df.describe()
# Out:
#         Age
# count   1.0
# mean   19.0
# std     NaN
# min    19.0
# 25%    19.0
# 50%    19.0
# 75%    19.0
# max    19.0

# %%
df.describe(include='all')
# Out:
#         Name   Age         Dob
# count      3   1.0           2
# unique     3   NaN           2
# top     Ashi   NaN  03-01-2004
# freq       1   NaN           1
# mean     NaN  19.0         NaN
# std      NaN   NaN         NaN
# min      NaN  19.0         NaN
# 25%      NaN  19.0         NaN
# 50%      NaN  19.0         NaN
# 75%      NaN  19.0         NaN
# max      NaN  19.0         NaN

# %%
df['Name']
# Out:
# 0      Ashi
# 1      Hari
# 2    Sarasu
# Name: Name, dtype: object

# %%
df.Dob
# Out:
# 0    03-01-2004
# 1          None
# 2    10-06-2004
# Name: Dob, dtype: object

# %%
df['Dob'][0]
# Out:
# '03-01-2004'

# %%
df[['Name','Dob']]
# Out:
#      Name         Dob
# 0    Ashi  03-01-2004
# 1    Hari        None
# 2  Sarasu  10-06-2004

# %%
df.loc[0][0]
# Out:
# 'Ashi'

# %%
df.loc[0,'Name']
# Out:
# 'Ashi'

# %%
df.iloc[0,1]
# Out:
# 19.0

# %%
df["Name"][0]='Ashikha'
df
# Out:
# <ipython-input-139-4602ad644fc4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Name"][0]='Ashikha'
#       Name   Age         Dob
# 0  Ashikha  19.0  03-01-2004
# 1     Hari   NaN        None
# 2   Sarasu   NaN  10-06-2004

# %%
df.loc[0,'Name']='Ashi'
df
# Out:
#      Name   Age         Dob
# 0    Ashi  19.0  03-01-2004
# 1    Hari   NaN        None
# 2  Sarasu   NaN  10-06-2004

# %%
df=pd.read_html("https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films")
df
# Out:
# [   0                                        1
#  0  *  Denotes films still playing in theatres,
#      Rank                             Film Gross ₹ crore (est.)  Year  \
#  0      1                           Dangal    1,968.03–2,023.81  2016
#  1      2      Baahubali 2: The Conclusion             1810.595  2017
#  2      3                              RRR             1316.305  2022
#  3      4                 K.G.F: Chapter 2          1,200–1,250  2022
#  4      5                            Jawan              1117.83  2023
#  5      6                          Pathaan              1050.30  2023
#  6      7                Bajrangi Bhaijaan       910.285–918.18  2015
#  7      8                 Secret Superstar       858.428–875.78  2017
#  8      9                               PK       750.595–769.89  2014
#  9     10                              2.0               699.89  2018
#  10    11                          Gadar 2               690.54  2023
# ...

# %%
df1=pd.read_html("https://en.wikipedia.org/wiki/High-speed_rail_in_India")
df1
# Out:
# [                                        Speed                  Type  \
#  0                          <110 km/h (68 mph)     Conventional rail
#  1   >110 km/h (68 mph) and <130 km/h (81 mph)         Group B lines
#  2   >130 km/h (81 mph) and <160 km/h (99 mph)         Group A lines
#  3  >160 km/h (99 mph) and <200 km/h (120 mph)  Semi-high-speed rail
#  4                         >200 km/h (120 mph)       High-speed rail
#
#                    Length
#  0  67,869 km (42,172 mi)
#  1  67,869 km (42,172 mi)
#  2  67,869 km (42,172 mi)
#  3        174 km (108 mi)
#  4        508 km (316 mi)  ,
#                                 High-speed Corridor                      Speed  \
#                                 High-speed Corridor                       km/h
#  0                                        North[35]                  North[35]
#  1          Delhi–Varanasi high-speed rail corridor                        320
# ...

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(df.item_price[0])
# Out:
# str

# %%
df.item_price=df.item_price.str.replace('$','')
df.head(10)
# Out:
# <ipython-input-42-5f86cc00013c>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
# ...

# %%
df.item_price=df.item_price.astype(float)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
type(df.item_price[0])
# Out:
# numpy.float64

# %%
df.item_price*100
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
df.item_name.unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df_drink=df[df.item_price<1.1]
df_drink
# Out:
#       order_id  quantity      item_name choice_description  item_price
# 28          14         1    Canned Soda       [Dr. Pepper]        1.09
# 34          17         1  Bottled Water                NaN        1.09
# 53          24         1    Canned Soda           [Sprite]        1.09
# 87          38         1  Bottled Water                NaN        1.09
# 107         47         1    Canned Soda       [Dr. Pepper]        1.09
# ...        ...       ...            ...                ...         ...
# 3936      1578         1    Canned Soda  [Diet Dr. Pepper]        1.09
# 4001      1602         1  Bottled Water                NaN        1.09
# 4008      1604         1    Canned Soda        [Diet Coke]        1.09
# 4051      1621         1    Canned Soda           [Sprite]        1.09
# 4069      1629         1  Bottled Water                NaN        1.09
#
# [106 rows x 5 columns]

# %%
df_drink.item_name.unique()
# Out:
# array(['Canned Soda', 'Bottled Water'], dtype=object)

# %%
df_drink.item_name.nunique()
# Out:
# 2

# %%
df_drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
import pandas as pd
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df[df.item_name=='Steak Burrito']
# Out:
#       order_id  quantity      item_name  \
# 7            4         1  Steak Burrito
# 9            5         1  Steak Burrito
# 31          16         1  Steak Burrito
# 43          20         1  Steak Burrito
# 46          21         1  Steak Burrito
# ...        ...       ...            ...
# 4546      1807         1  Steak Burrito
# 4607      1829         1  Steak Burrito
# 4610      1830         1  Steak Burrito
# 4617      1833         1  Steak Burrito
# 4618      1833         1  Steak Burrito
#
#                                      choice_description item_price
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 31    [[Roasted Chili Corn Salsa (Medium), Fresh Tom...     $8.99
# 43    [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    $11.75
# 46    [Tomatillo-Red Chili Salsa (Hot), [Rice, Fajit...     $8.99
# ...                                                 ...        ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df.choice_description
# Out:
# 1                                            [Clementine]
# 2                                                 [Apple]
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 3376, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')]
# Out:
#       order_id  quantity             item_name  \
# 4            2         2          Chicken Bowl
# 7            4         1         Steak Burrito
# 9            5         1         Steak Burrito
# 11           6         1  Chicken Crispy Tacos
# 12           6         1    Chicken Soft Tacos
# ...        ...       ...                   ...
# 4604      1828         1          Chicken Bowl
# 4608      1829         1        Veggie Burrito
# 4611      1830         1        Veggie Burrito
# 4612      1831         1         Carnitas Bowl
# 4617      1833         1         Steak Burrito
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 9     [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25
# 11    [Roasted Chili Corn Salsa, [Fajita Vegetables,...     $8.75
# ...

# %%
df[df.choice_description.str.contains('Black Beans')].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[df.choice_description.str.contains('Black Beans')].value_counts()
# Out:
# order_id  quantity  item_name              choice_description                                                                                    item_price
# 319       1         Chicken Bowl           [Tomatillo-Green Chili Salsa (Medium), Black Beans]                                                   $8.49         2
# 972       1         Chicken Bowl           [Tomatillo Red Chili Salsa, [Rice, Black Beans, Sour Cream, Cheese, Lettuce]]                         $8.75         2
# 1507      1         Chicken Burrito        [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                $8.75         2
# 610       1         Chicken Burrito        [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Lettuce]]             $8.75         2
# 103       1         Steak Burrito          [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]              $11.75        2
# ...

# %%
df.item_price=df.item_price.str.replace('$','')
df.item_price=df.item_price.astype(float)
# Out:
# <ipython-input-26-eb09b0b47249>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')

# %%
df[(df.item_price < 10) & (df.item_name=='Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
df[(df.item_price < 10) & (df.item_name=='Chicken Bowl')].sort_values(["item_price"])
# Out:
#       order_id  quantity     item_name  \
# 3664      1466         1  Chicken Bowl
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3396      1362         1  Chicken Bowl
# 1645       665         1  Chicken Bowl
# ...        ...       ...           ...
# 1876       759         1  Chicken Bowl
# 1852       751         1  Chicken Bowl
# 1851       750         1  Chicken Bowl
# 1829       740         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3396  [Tomatillo-Green Chili Salsa (Medium), [Pinto ...        8.49
# 1645  [[Fresh Tomato Salsa (Mild), Tomatillo-Red Chi...        8.49
# ...                                                 ...         ...
# ...

# %%
import pandas as pd
movie=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
movie
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movie[(movie.star_rating >= 8) & (movie.content_rating=='PG-13')]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 25           8.6                                  Life Is Beautiful
# 26           8.6                       Once Upon a Time in the West
# 43           8.5                              The Dark Knight Rises
# 53           8.5                                       The Prestige
# 60           8.5                                           3 Idiots
# 69           8.4                                  Princess Mononoke
# ...

# %%
movie[(movie.star_rating >= 8) & (movie.content_rating=='PG-13')].value_counts()
# Out:
# star_rating  title                                                   content_rating  genre      duration  actors_list
# 8.0          Big Fish                                                PG-13           Adventure  125       [u'Ewan McGregor', u'Albert Finney', u'Billy Crudup']                   1
# 8.1          The Help                                                PG-13           Drama      146       [u'Emma Stone', u'Viola Davis', u'Octavia Spencer']                     1
#              The Perks of Being a Wallflower                         PG-13           Drama      102       [u'Logan Lerman', u'Emma Watson', u'Ezra Miller']                       1
#              The Sea Inside                                          PG-13           Biography  125       [u'Javier Bardem', u'Bel\xe9n Rueda', u'Lola Due\xf1as']                1
# ...

# %%
movie[(movie.star_rating >= 8) & (movie.content_rating=='PG-13')].sort_values(['duration'])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 305          8.0                                         Persepolis
# 232          8.1                                  Chungking Express
# 356          8.0                                         The Artist
# 279          8.1                    The Perks of Being a Wallflower
# 370          8.0                             Hannah and Her Sisters
# 314          8.0                            Crimes and Misdemeanors
# 379          8.0                                Edward Scissorhands
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 391          8.0                                   Edge of Tomorrow
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# ...

# %%
movie[movie.actors_list.str.contains('Aamir Khan')]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
movie[movie.actors_list.str.contains('Aamir Khan')].value_counts()
# Out:
# star_rating  title                              content_rating  genre      duration  actors_list
# 8.3          Dil Chahta Hai                     NOT RATED       Comedy     183       [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Khanna']    1
#              Lagaan: Once Upon a Time in India  PG              Adventure  224       [u'Aamir Khan', u'Gracy Singh', u'Rachel Shelley']      1
# 8.4          Rang De Basanti                    NOT RATED       Drama      157       [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']         1
# 8.5          3 Idiots                           PG-13           Comedy     170       [u'Aamir Khan', u'Madhavan', u'Mona Singh']             1
#              Taare Zameen Par                   PG              Drama      165       [u'Darsheel Safary', u'Aamir Khan', u'Tanay Chheda']    1
# dtype: int64

# %%
movie[movie.actors_list.str.contains('Aamir Khan')].value_counts().sum()
# Out:
# 5

# %%
movie[movie.actors_list.str.contains('Aamir Khan')].sort_values(['duration','star_rating'],ascending=(True,False))
# Out:
#      star_rating                              title content_rating      genre  \
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
import pandas as pd
drinks=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     193 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
drinks.beer_servings.min()
# Out:
# 0

# %%
drinks.beer_servings.max()
# Out:
# 376

# %%
drinks[drinks.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000

# %%
drinks[drinks.continent=='Asia'].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %%
drinks.groupby('continent').beer_servings.max().agg(['mean','min','max'])
# Out:
# mean    318.0
# min     247.0
# max     376.0
# Name: beer_servings, dtype: float64

# %%
drinks.groupby('continent').beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
